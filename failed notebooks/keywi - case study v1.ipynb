# %% [markdown]
# # Lib and labels import

# %%
#load libs
from google.colab import files
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
np.warnings.filterwarnings('ignore')

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/ressources/keywi/labels.csv'
df = pd.read_csv(filename, sep=',', index_col=0)

# %%
df
# Out:
#                                                  label
# hash
# 762da493542c9d185c7403be3f981994               landing
# 3102c582cd015d0588735e8de86c2ad0               landing
# 4e9d74b8d4e652b9f25f6cd5ed0852ca               landing
# 34ac0c476606be7a786f909388d7f4aa               landing
# 0bb84fb0c6a9b709a0d377c2a9edbbd7               landing
# ...                                                ...
# 74785a6c9d31dcee7b8b6f9bbc43668b   company_information
# 2ec48f400548071fc1016c207d9904bd   company_information
# cf31419363312fe2d51074df9f1f5555   company_information
# df10b7f8dbe4b652ae7ca52fc8e18827   company_information
# 3e4030c44fc93b4cf3a347d387155466   company_information
#
# [9735 rows x 1 columns]

# %% [markdown]
# We observe balanced labels:

# %%
df.value_counts()
# Out:
#  label
#  social                 1997
#  landing                1975
#  company_information    1950
#  commercial             1936
#  article                1877
# dtype: int64

# %% [markdown]
# When sampling the dataset, the labels are still equally balanced:

# %%
df.sample(frac=0.1).value_counts()
# Out:
#  label
#  company_information    208
#  commercial             207
#  landing                195
#  social                 194
#  article                170
# dtype: int64

# %% [markdown]
# # Import single html (Beautiful Soup)

# %%
from bs4 import BeautifulSoup

# %%
with open("/content/drive/MyDrive/Colab Notebooks/ressources/keywi/000c8dbce2c87572ff60e83280a8bed2.html") as fp:
    soup = BeautifulSoup(fp, 'html.parser')

# %%
text_list = []
for text in soup.find_all('p'):
  text_list.append(text.get_text().strip().lower())

# %%
lines = ''.join(text_list)

# %%
soup.title.string
# Out:
# 'Advertising agency - Wikipedia'

# %% [markdown]
# # Noun extraction from HTML:

# %%
import nltk
nltk.download("book")

# %%
tokenized = nltk.word_tokenize(lines)
nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if((pos[:2] == 'NN') or (pos[:2] == 'VB'))]
print (nouns)
# Out:
# ['advertising', 'agency', 'referred', 'agency', 'ad', 'agency', 'is', 'business', 'dedicated', 'creating', 'planning', 'handling', 'advertising', 'forms', 'promotion', 'marketing', 'clients', 'ad', 'agency', 'is', 'client', 'be', 'department', 'agency', 'provides', 'point', 'view', 'effort', 'selling', 'client', 'products', 'services', 'firm', 'agency', 'handle', 'marketing', 'branding', 'strategies', 'promotions', 'clients', 'include', 'sales', 'ad', 'agency', 'clients', 'include', 'businesses', 'corporations', 'organizations', 'agencies', 'agencies', 'be', 'hired', 'produce', 'television', 'advertisements', 'radio', 'advertisements', 'advertising', 'advertising', 'marketing', 'advertising', 'part', 'advertising', 'campaign.the', 'acknowledged', 'advertising', 'agency', 'was', 'taylor', 'agency', 'started', 'james', "'jem", 'street', 'london', 'evolved', 'bull', 'holmes', 'recruitment', 'advertising', 'agency', 'went', 'business', '1980s', ']', '[', ']', 'george', 'reynell', 'officer', 'london', 'gazette', 'set', 'advertising', 'agencies', 'london', ']', 'remained', 'family', 'business', "'reynell", 'son', 'is', 'part', 'tmp', 'worldwide', 'agency', 'ireland', 'brand', 'tmp', 'reynell', ']', 'agency', 'traded', 'was', 'founded', 'charles', 'barker', 'firm', 'established', 'traded', "'barkers", 'went', 'administration.volney', 'b.', 'palmer', 'opened', 'advertising', 'agency', 'philadelphia', 'agency', 'placed', 'ads', 'produced', 'clients', 'newspapers', ']', 'mathew', 'brady', 'created', 'advertisement', 'placed', 'ad', 'york', 'paper', 'offering', 'produce', 'photographs', 'ambrotypes', 'daguerreotypes', 'ads', 'were', 'typeface', 'fonts', 'were', 'text', 'publication', 'advertisements', 'time', 'newspaper', 'ads', 'were', 'set', 'agate', 'agate', 'use', 'fonts', 'caused', 'sensation', ']', 'year', 'robert', 'e.', 'bonner', 'ran', 'full-page', 'ad', 'newspaper', ']', 'william', 'james', 'carlton', 'began', 'selling', 'advertising', 'space', 'magazines', 'ayer', 'age', 'created', 'advertising', 'agency', 'philadelphia', 'called', 'n.w', 'ayer', 'son', 'was', 'advertising', 'agency', 'america', 'dissolved', 'james', 'thompson', 'joined', 'carlton', 'firm', 'thompson', 'became', 'salesman', 'purchasing', 'company', 'renaming', 'james', 'walter', 'company', 'realizing', 'sell', 'space', 'company', 'provided', 'service', 'developing', 'content', 'advertisers', 'thompson', 'hired', 'writers', 'artists', 'form', 'known', 'department', 'advertising', 'agency', 'is', 'credited', 'father', 'magazine', 'advertising', '[', 'advertising', 'age', 'commemorated', 'years', 'agency', 'noting', 'history', 'expansion', 'seems', 'match', 'history', 'advertising', 'globalization', 'advertising', 'originates', 'days', 'century', 'advertising', 'agencies', 'began', 'process', 'opening', 'offices', 'world', 'wars', 'accelerated', 'globalization', 'part', 'twentieth', 'century.mccann', 'agency', 'established', 'york', 'city', 'opened', 'offices', 'was', 'followed', 'offices', 'opening', 'south', 'america', 'australia', '[', 'companies', 'j.', 'walter', 'thompson', 'adopted', 'strategy', 'expand', 'order', 'provide', 'advertising', 'services', 'clients', 'operated.in', '1960s', 'agencies', 'began', 'realize', 'opportunities', 'associated', 'globalization', 'expanding', 'gives', 'wider', 'markets.studies', 'show', 'advertising', 'agencies', 'tend', 'have', 'shared', 'sense', 'purpose', 'clients', 'collaboration', 'includes', 'set', 'client', 'objectives', 'agencies', 'feel', 'shared', 'sense', 'ownership', 'process', 'advertisements', 'start', 'clients', 'building', 'relationship', 'agencies', 'work', 'figure', 'objectives', 'are', 'clients', 'trust', 'agencies', 'do', 'jobs', 'resources', 'have', 'provided', 'breakdowns', 'relationships', 'were', 'occur', 'agencies', 'felt', 'feel', 'do', 'have', 'status', 'advertising', 'agencies', 'tend', 'be', 'position', 'take', 'lead', 'projects', '[', ']', 'results', 'are', 'is', 'relationship.stronger', 'coll ...

# %% [markdown]
# # TF-IDF extraction from text (SKlearn)
#
# We should parse several files to test it, so we start with the default example

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = [
    'This is the first document.',
    'This document is the second document.',
    'And this is the third one.',
    'Is this the first document?',
]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)
vectorizer.get_feature_names_out()

print(X.shape)
# Out:
# (4, 9)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['and', 'document', 'first', 'is', 'one', 'second', 'the', 'third',
#        'this'], dtype=object)

# %%
pd.DataFrame(X)
# Out:
#                                                    0
# 0    (0, 1)\t0.46979138557992045\n  (0, 2)\t0.580...
# 1    (0, 5)\t0.5386476208856763\n  (0, 1)\t0.6876...
# 2    (0, 4)\t0.511848512707169\n  (0, 7)\t0.51184...
# 3    (0, 1)\t0.46979138557992045\n  (0, 2)\t0.580...

# %% [markdown]
# ## Testing on the sentences of the HTML input file:

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(new_sentences)
vectorizer.get_feature_names_out()
# Out:
# array(['1960s', '1980s', 'accelerated', 'account', 'acknowledged',
#        'acting', 'ad', 'administration', 'adopted', 'ads',
#        'advertisement', 'advertisements', 'advertisers', 'advertising',
#        'agate', 'age', 'agencies', 'agency', 'agents', 'ambrotypes',
#        'america', 'are', 'artists', 'associated', 'attention',
#        'audiences', 'australia', 'ayer', 'barker', 'barkers', 'be',
#        'became', 'been', 'began', 'bond', 'bonner', 'brady', 'brand',
#        'branding', 'breakdowns', 'breaking', 'building', 'builds', 'bull',
#        'business', 'businesses', 'called', 'campaign', 'capture',
#        'carlton', 'case', 'caused', 'century', 'charles', 'chemistry',
#        'cities', 'city', 'client', 'clients', 'clutter', 'collaboration',
#        'comes', 'commemorated', 'commissions', 'communication',
#        'companies', 'company', 'consumers', 'content', 'contribute',
#        'corporations', 'created', 'creating', 'creativity', 'credited',
#        'daguerreotypes', 'days', 'dedicated', 'department', 'developing',
#        'dislikes', 'dissolved', 'do', 'effort', 'empathy', 'established',
#        'estimated', 'evolved', 'expand', 'expanding', 'expansion',
#        'expected', 'family', 'father', 'feel', 'felt', 'figure',
#        'finding', 'firm', 'followed', 'fonts', 'form', 'forms', 'founded',
#        'frequency', 'full', 'gazette', 'george', 'get', 'gives',
#        'globalization', 'goes', 'half', 'handle', 'handling', 'happens',
#        'has', 'have', 'headquarters', 'hired', 'history', 'hobbies',
#        'holding', 'holmes', 'include', 'includes', 'income', 'indicated',
#        'involved', 'ireland', 'is', 'james', 'jem', 'jobs', 'joined',
#        'known', 'lead', 'length', 'likes', 'list', 'london', 'made',
#        'magazine', 'magazines', 'majority', 'make', 'marketing',
#        'markets', 'match', 'mathew', 'mccann', 'media', 'meetings',
#        'message', 'middle', 'mindset', 'nature', 'newspaper',
#        'newspapers', 'noting', 'objectives', 'occasions', 'occur',
#        'offer', 'offering', 'officer', 'offices', 'opened', 'opening',
#        'operated', 'opportunities', 'order', 'organizations',
#        'originates', 'ownership', 'page', 'paid', 'palmer', 'paper',
#        'part', 'parties', 'passions', 'perceived', 'philadelphia',
#        'photographs', 'placed', 'planners', 'planning', 'point', 'points',
#        'position', 'principals', 'process', 'produce', 'produced',
#        'product', 'products', 'project', 'projects', 'promotion',
#        'promotions', 'provide', 'provided', 'provides', 'prowess',
#        'publication', 'purchasing', 'purpose', 'radio', 'ran', 'realize',
#        'realizing', 'recruitment', 'referred', 'relationship',
#        'relationships', 'remained', 'renaming', 'researchers',
#        'resources', 'respect', 'results', 'revenues', 'reynell', 'robert',
#        'sales', 'salesman', 'see', 'seems', 'seen', 'sell', 'selling',
#        'seniority', 'sensation', 'sense', 'service', 'services', 'set',
#        'shared', 'show', 'sides', 'situations', 'sold', 'son', 'south',
#        'space', 'start', 'started', 'status', 'strategies', 'strategy',
#        'street', 'studies', 'suggested', 'surprised', 'take', 'taylor',
#        'television', 'tend', 'text', 'think', 'thompson', 'time', 'tmp',
#        'today', 'towards', 'traded', 'trait', 'trust', 'trusting', 'type',
#        'typeface', 'understanding', 'use', 'view', 'views', 'volney',
#        'walter', 'wars', 'was', 'went', 'were', 'wider', 'william',
#        'work', 'world', 'worldwide', 'writers', 'writing', 'year',
#        'years', 'york'], dtype=object)

# %% [markdown]
# Too much stuff, lets try only the verbs:

# %%
import nltk
nltk.download("book")

# %%
def get_verbs_and_nouns(input_string):
  tokenized = nltk.word_tokenize(input_string)
  verb_nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if((pos[:2] == 'NN') or (pos[:2] == 'VB'))]
  return verb_nouns

new_sentences = []
for sentence in text_list:
  new_sentences.append(' '.join(get_verbs_and_nouns(sentence)))

# %%
new_sentences
# Out:
# ['',
#  'advertising agency referred agency ad agency is business dedicated creating planning handling advertising forms promotion marketing clients ad agency is client be department agency provides point view effort selling client products services firm agency handle marketing branding strategies promotions clients include sales',
#  'ad agency clients include businesses corporations organizations agencies agencies be hired produce television advertisements radio advertisements advertising advertising marketing advertising part advertising campaign',
#  "acknowledged advertising agency was taylor agency started james 'jem street london evolved bull holmes recruitment advertising agency went business 1980s ] [ ] george reynell officer london gazette set advertising agencies london ] remained family business 'reynell son is part tmp worldwide agency ireland brand tmp reynell ] agency traded was founded charles barker firm established traded 'barkers went administration",
#  'volney b. palmer opened advertising agency philadelphia agency placed ads produced clients newspapers ]',
#  'mathew brady created advertisement placed ad york paper offering produce photographs ambrotypes daguerreotypes ads were typeface fonts were text publication advertisements time newspaper ads were set agate agate use fonts caused sensation ] year robert e. bonner ran full-page ad newspaper ]',
#  'william james carlton began selling advertising space magazines ayer age created advertising agency philadelphia called n.w ayer son was advertising agency america dissolved james thompson joined carlton firm thompson became salesman purchasing company renaming james walter company realizing sell space company provided service developing content advertisers thompson hired writers artists form known department advertising agency is credited father magazine advertising [ advertising age commemorated years agency noting history expansion seems match history advertising ]',
#  'globalization advertising originates days century advertising agencies began process opening offices world wars accelerated globalization part century',
#  'mccann agency established york city opened offices was followed offices opening south america australia [ ]',
#  'companies j. walter thompson adopted strategy expand order provide advertising services clients operated',
#  '1960s agencies began realize opportunities associated globalization expanding gives wider markets',
#  'studies show advertising agencies tend have shared sense purpose clients collaboration includes set client objectives agencies feel shared sense ownership process advertisements start clients building relationship agencies work figure objectives are clients trust agencies do jobs resources have provided breakdowns relationships were occur agencies felt feel do have status advertising agencies tend be position take lead projects [ ] results are is relationship',
#  'collaboration happens situations chemistry has been established parties finding likes dislikes points view hobbies passions chemistry builds length client relationship frequency meetings respect goes parties was trait advertising agencies were perceived have was suggested occasions media planners researchers were involved project relationships clients ] planning is parties are involved bond sides understanding views mindset',
#  'advertising account planners are seen contribute towards collaboration planners advertising agencies tend be creating trusting relationship clients were seen prowess seniority have empathy process',
#  'advertising agencies are called are acting agents principals were media were are paid media sell advertising space clients century half advertising agencies made income commissions paid media selling space client [ ]',
#  'is case majority income comes media middle century agencies began offer services sold client services include writing text advertisement ]',
#  'use creativity agencies is advertising today is expected capture attention audiences message is get have been advertisements have surprised audiences was see advertisement nature use creativity is agencies make consumers think product brand type creativity is communication is breaking clutter ]',
#  'agencies estimated revenues [ ]',
#  'is list advertising agencies holding companies advertising agencies headquarters cities indicated']

# %% [markdown]
# # Testing more stuff

# %%
lines
# Out:
# 'an advertising agency, often referred to as a creative agency or an ad agency, is a business dedicated to creating, planning, and handling advertising and sometimes other forms of promotion and marketing for its clients. an ad agency is generally independent of the client; it may be an internal department or agency that provides an outside point of view to the effort of selling the client\'s products or services, or an outside firm. an agency can also handle overall marketing and branding strategies promotions for its clients, which may include sales as well.typical ad agency clients include businesses and corporations, non-profit organizations and private agencies. agencies may be hired to produce television advertisements, radio advertisements, online advertising, out-of-home advertising, mobile marketing, and ar advertising, as part of an advertising campaign.the first acknowledged advertising agency was william taylor in 1786. another early agency, started by james \'jem\' white in 1800 at fleet street, london, eventually evolved into white bull holmes, a recruitment advertising agency, that went out of business in the late 1980s.[1][2] in 1812 george reynell, an officer at the london gazette, set up another of the early advertising agencies, also in london.[1] this remained a family business until 1993, as \'reynell & son,\' and is now part of the tmp worldwide agency (uk and ireland) under the brand tmp reynell.[1] another early agency that traded until recently, was founded by charles barker, and the firm he established traded as \'barkers\' until 2009 when it went into administration.volney b. palmer opened the first american advertising agency, in philadelphia in 1850. this agency placed ads produced by its clients in various newspapers.[3]in 1856 mathew brady created the first modern advertisement when he placed an ad in the new york herald paper offering to produce "photographs, ambrotypes, and daguerreotypes." his ads were the first whose typeface and fonts were distinct from the text of the publication and from that of other advertisements. at that time all newspaper ads were set in agate and only agate. his use of larger distinctive fonts caused a sensation.[3] later that same year robert e. bonner ran the first full-page ad in a newspaper.[3]in 1864, william james carlton began selling advertising space in religious magazines. in 1869, francis ayer, at the age of 20, created the first full-service advertising agency in philadelphia, called n.w. ayer & son. it was the oldest advertising agency in america and dissolved in 2002.\njames walter thompson joined carlton\'s firm in 1868. thompson rapidly became their best salesman, purchasing the company in 1877 and renaming it the james walter thompson company. realizing that he could sell more space if the company provided the service of developing content for advertisers, thompson hired writers and artists to form the first known creative department in an advertising agency. he is credited as the "father of modern magazine advertising" in the us.[3] advertising age commemorated the first 100 years of the agency in 1964, noting that its  "history and expansion overseas seems peculiarly to match the whole history of modern advertising."[4]globalization of advertising originates in earlier days of the twentieth century. american advertising agencies began as the process of opening overseas offices before the two world wars and accelerated their globalization throughout the latter part of the twentieth century.mccann,  an agency established in new york city in 1902, opened its first european offices by 1927. it was followed up with offices opening in south america in 1935 and in australia in 1959.[5]companies such as j. walter thompson adopted a strategy to expand in order to provide advertising services wherever clients operated.in the 1960s and 1970s, english agencies began to realize the overseas opportunities associated with globalization.[6] expanding overseas give ...

# %%
#remove stop words

from nltk.corpus import stopwords
from nltk import word_tokenize

stop = set(stopwords.words('english'))

# lines
text_wihtout_stop_words = ' '.join([i for i in word_tokenize(lines.lower()) if i not in stop])

# %%
text_wihtout_stop_words
# Out:
# "advertising agency , often referred creative agency ad agency , business dedicated creating , planning , handling advertising sometimes forms promotion marketing clients . ad agency generally independent client ; may internal department agency provides outside point view effort selling client 's products services , outside firm . agency also handle overall marketing branding strategies promotions clients , may include sales well.typical ad agency clients include businesses corporations , non-profit organizations private agencies . agencies may hired produce television advertisements , radio advertisements , online advertising , out-of-home advertising , mobile marketing , ar advertising , part advertising campaign.the first acknowledged advertising agency william taylor 1786. another early agency , started james 'jem ' white 1800 fleet street , london , eventually evolved white bull holmes , recruitment advertising agency , went business late 1980s . [ 1 ] [ 2 ] 1812 george reynell , officer london gazette , set another early advertising agencies , also london . [ 1 ] remained family business 1993 , 'reynell & son , ' part tmp worldwide agency ( uk ireland ) brand tmp reynell . [ 1 ] another early agency traded recently , founded charles barker , firm established traded 'barkers ' 2009 went administration.volney b. palmer opened first american advertising agency , philadelphia 1850. agency placed ads produced clients various newspapers . [ 3 ] 1856 mathew brady created first modern advertisement placed ad new york herald paper offering produce `` photographs , ambrotypes , daguerreotypes . '' ads first whose typeface fonts distinct text publication advertisements . time newspaper ads set agate agate . use larger distinctive fonts caused sensation . [ 3 ] later year robert e. bonner ran first full-page ad newspaper . [ 3 ] 1864 , william james carlton began selling advertising space religious magazines . 1869 , francis ayer , age 20 , created first full-service advertising agency philadelphia , called n.w . ayer & son . oldest advertising agency america dissolved 2002. james walter thompson joined carlton 's firm 1868. thompson rapidly became best salesman , purchasing company 1877 renaming james walter thompson company . realizing could sell space company provided service developing content advertisers , thompson hired writers artists form first known creative department advertising agency . credited `` father modern magazine advertising '' us . [ 3 ] advertising age commemorated first 100 years agency 1964 , noting `` history expansion overseas seems peculiarly match whole history modern advertising . `` [ 4 ] globalization advertising originates earlier days twentieth century . american advertising agencies began process opening overseas offices two world wars accelerated globalization throughout latter part twentieth century.mccann , agency established new york city 1902 , opened first european offices 1927. followed offices opening south america 1935 australia 1959 . [ 5 ] companies j. walter thompson adopted strategy expand order provide advertising services wherever clients operated.in 1960s 1970s , english agencies began realize overseas opportunities associated globalization . [ 6 ] expanding overseas gives potential wider markets.studies show successful advertising agencies tend shared sense purpose clients collaboration . includes common set client objectives agencies feel shared sense ownership strategic process . successful advertisements start clients building good relationship agencies work together figure objectives . clients must trust agencies jobs correctly accordingly resources provided . breakdowns relationships likely occur agencies felt undermined , subjugated , even feel n't equal status . traditionally advertising agencies tend position take lead projects [ 7 ] results best collaborative relationship.stronger collaboration happens situations personal chemistry established parties . finding similar like ...

# %%
from nltk.stem import WordNetLemmatizer 


# Init the Wordnet Lemmatizer
lemmatizer = WordNetLemmatizer()
word_list = nltk.word_tokenize(text_wihtout_stop_words)
lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
print(lemmatized_output)
# Out:
# advertising agency , often referred creative agency ad agency , business dedicated creating , planning , handling advertising sometimes form promotion marketing client . ad agency generally independent client ; may internal department agency provides outside point view effort selling client 's product service , outside firm . agency also handle overall marketing branding strategy promotion client , may include sale well.typical ad agency client include business corporation , non-profit organization private agency . agency may hired produce television advertisement , radio advertisement , online advertising , out-of-home advertising , mobile marketing , ar advertising , part advertising campaign.the first acknowledged advertising agency william taylor 1786. another early agency , started james 'jem ' white 1800 fleet street , london , eventually evolved white bull holmes , recruitment advertising agency , went business late 1980s . [ 1 ] [ 2 ] 1812 george reynell , officer london gazette , set another early advertising agency , also london . [ 1 ] remained family business 1993 , 'reynell & son , ' part tmp worldwide agency ( uk ireland ) brand tmp reynell . [ 1 ] another early agency traded recently , founded charles barker , firm established traded 'barkers ' 2009 went administration.volney b. palmer opened first american advertising agency , philadelphia 1850. agency placed ad produced client various newspaper . [ 3 ] 1856 mathew brady created first modern advertisement placed ad new york herald paper offering produce `` photograph , ambrotypes , daguerreotype . '' ad first whose typeface font distinct text publication advertisement . time newspaper ad set agate agate . use larger distinctive font caused sensation . [ 3 ] later year robert e. bonner ran first full-page ad newspaper . [ 3 ] 1864 , william james carlton began selling advertising space religious magazine . 1869 , francis ayer , age 20 , created first full-service advertising agency philadelphia , called n.w . ayer & son . oldest advertising agency america dissolved 2002. james walter thompson joined carlton 's firm 1868. thompson rapidly became best salesman , purchasing company 1877 renaming james walter thompson company . realizing could sell space company provided service developing content advertiser , thompson hired writer artist form first known creative department advertising agency . credited `` father modern magazine advertising '' u . [ 3 ] advertising age commemorated first 100 year agency 1964 , noting `` history expansion overseas seems peculiarly match whole history modern advertising . `` [ 4 ] globalization advertising originates earlier day twentieth century . american advertising agency began process opening overseas office two world war accelerated globalization throughout latter part twentieth century.mccann , agency established new york city 1902 , opened first european office 1927. followed office opening south america 1935 australia 1959 . [ 5 ] company j. walter thompson adopted strategy expand order provide advertising service wherever client operated.in 1960s 1970s , english agency began realize overseas opportunity associated globalization . [ 6 ] expanding overseas give potential wider markets.studies show successful advertising agency tend shared sense purpose client collaboration . includes common set client objective agency feel shared sense ownership strategic process . successful advertisement start client building good relationship agency work together figure objective . client must trust agency job correctly accordingly resource provided . breakdown relationship likely occur agency felt undermined , subjugated , even feel n't equal status . traditionally advertising agency tend position take lead project [ 7 ] result best collaborative relationship.stronger collaboration happens situation personal chemistry established party . finding similar like dislike point view , even hobby passion . personal chemistry build length client  ...

# %%
import spacy
nlp = spacy.load('en', disable=['parser', 'ner'])
doc = nlp(text_wihtout_stop_words)
print(" ".join([token.lemma_ for token in doc]))
# Out:
# advertising agency , often refer creative agency ad agency , business dedicate creating , planning , handle advertising sometimes form promotion marketing client . ad agency generally independent client ; may internal department agency provide outside point view effort sell client 's product service , outside firm . agency also handle overall marketing brand strategy promotion client , may include sale well.typical ad agency client include business corporation , non - profit organization private agency . agency may hire produce television advertisement , radio advertisement , online advertising , out - of - home advertising , mobile marketing , ar advertising , part advertising campaign.the first acknowledge advertising agency william taylor 1786 . another early agency , start james ' jem ' white 1800 fleet street , london , eventually evolve white bull holmes , recruitment advertising agency , go business late 1980 . [ 1 ] [ 2 ] 1812 george reynell , officer london gazette , set another early advertising agency , also london . [ 1 ] remain family business 1993 , ' reynell & son , ' part tmp worldwide agency ( uk ireland ) brand tmp reynell . [ 1 ] another early agency trade recently , found charles barker , firm establish trade ' barker ' 2009 go administration.volney b. palmer open first american advertising agency , philadelphia 1850 . agency place ad produce client various newspaper . [ 3 ] 1856 mathew brady create first modern advertisement place ad new york herald paper offering produce ` ` photograph , ambrotype , daguerreotype . '' ad first whose typeface font distinct text publication advertisement . time newspaper ad set agate agate . use large distinctive font cause sensation . [ 3 ] later year robert e. bonner run first full - page ad newspaper . [ 3 ] 1864 , william james carlton begin sell advertising space religious magazine . 1869 , francis ayer , age 20 , create first full - service advertising agency philadelphia , call n.w . ayer & son . old advertising agency america dissolve 2002 . james walter thompson join carlton 's firm 1868 . thompson rapidly become good salesman , purchase company 1877 rename james walter thompson company . realizing could sell space company provide service develop content advertiser , thompson hire writer artist form first know creative department advertising agency . credit ` ` father modern magazine advertising '' -PRON- . [ 3 ] advertising age commemorate first 100 year agency 1964 , note ` ` history expansion overseas seem peculiarly match whole history modern advertising . ` ` [ 4 ] globalization advertising originate early day twentieth century . american advertising agency begin process open overseas office two world war accelerate globalization throughout latter part twentieth century.mccann , agency establish new york city 1902 , open first european office 1927 . follow office open south america 1935 australia 1959 . [ 5 ] company j. walter thompson adopt strategy expand order provide advertising service wherever client operated.in 1960s 1970 , english agency begin realize overseas opportunity associate globalization . [ 6 ] expand overseas give potential wide markets.studie show successful advertising agency tend share sense purpose client collaboration . include common set client objective agency feel shared sense ownership strategic process . successful advertisement start client build good relationship agency work together figure objective . client must trust agency job correctly accordingly resource provide . breakdown relationship likely occur agency feel undermined , subjugate , even feel n't equal status . traditionally advertising agency tend position take lead project [ 7 ] result good collaborative relationship.stronger collaboration happen situation personal chemistry establish party . find similar like dislikes point view , even hobbie passion . personal chemistry build length client relationship , frequency meeting , far mutual respect go party . one trait adv ...

# %% [markdown]
# # Conclusion
#
# * we can extract nouns from an html file
# * we can compute their relative frequencies
#
# # Next steps
#
# * Select part of the dataset to look at specific words => do all landing pages contain all the same words ?
#
# * How to select part of this dataset ? Only one class or multiple ?
