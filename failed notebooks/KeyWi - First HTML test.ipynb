# %% [markdown]
# # Lib import

# %%
#load libs
from google.colab import files
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
np.warnings.filterwarnings('ignore')

# %% [markdown]
# # Extract a lot of HTML files

# %%
# !unzip -u "/content/drive/MyDrive/Colab Notebooks/ressources/keywi/dataset/html_pages.zip" -d "/content/drive/MyDrive/Colab Notebooks/ressources/keywi/dataset/"

# %% [markdown]
# # Import filenames and extract hashes

# %%
import cv2
import glob
path = "/content/drive/MyDrive/Colab Notebooks/ressources/keywi/dataset/*"

filenames = []

for file in glob.glob(path):
   filenames.append(file)


filenames_df = pd.DataFrame(filenames, columns=['raw_filename'])

# %% [markdown]
# Remove zip file from the list

# %%
filenames_df = filenames_df[~filenames_df.raw_filename.str.contains('zip')]

# %% [markdown]
# Extract the hash

# %%
temp_df = filenames_df.raw_filename.str.split('dataset/', expand=True)
filenames_df['hash'] = temp_df[1].str.split('.html', expand=True)[0]

# %%
filenames_df
# Out:
#                                            raw_filename  \
# 1     /content/drive/MyDrive/Colab Notebooks/ressour...
# 2     /content/drive/MyDrive/Colab Notebooks/ressour...
# 3     /content/drive/MyDrive/Colab Notebooks/ressour...
# 4     /content/drive/MyDrive/Colab Notebooks/ressour...
# 5     /content/drive/MyDrive/Colab Notebooks/ressour...
# ...                                                 ...
# 3227  /content/drive/MyDrive/Colab Notebooks/ressour...
# 3228  /content/drive/MyDrive/Colab Notebooks/ressour...
# 3229  /content/drive/MyDrive/Colab Notebooks/ressour...
# 3230  /content/drive/MyDrive/Colab Notebooks/ressour...
# 3231  /content/drive/MyDrive/Colab Notebooks/ressour...
#
#                                   hash
# 1     003ff5c19b37a2b79bb169b95d2e30de
# 2     0043a18428f34c7aebba1146780dc77b
# 3     00569945c8433ea0e859e78d3973690c
# 4     0057fa9ca754fb8e46a3b74f07942bdc
# 5     00837ecb034b5f4570d1e073a597f6cf
# ...                                ...
# 3227  ff85349e89a648edb9cd359c2378328c
# 3228  ff8f4abb330a219836b3da6fb9f66742
# 3229  ffdd799c052b7994619c51a1abe20316
# 3230  ffef4a742bffa072fe251922c9a46b30
# 3231  fffbf251bbb255172584ca1791d8f775
#
# [3231 rows x 2 columns]

# %% [markdown]
# # Import labels into df

# %%
labels = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ressources/keywi/labels.csv')

# %%
labels.columns = ['hash', 'label']

# %% [markdown]
# # Merge partial dataset to labels

# %%
dataset = pd.merge(left=filenames_df,right=labels,on='hash')

# %%
dataset
# Out:
#                                            raw_filename  \
# 0     /content/drive/MyDrive/Colab Notebooks/ressour...
# 1     /content/drive/MyDrive/Colab Notebooks/ressour...
# 2     /content/drive/MyDrive/Colab Notebooks/ressour...
# 3     /content/drive/MyDrive/Colab Notebooks/ressour...
# 4     /content/drive/MyDrive/Colab Notebooks/ressour...
# ...                                                 ...
# 3237  /content/drive/MyDrive/Colab Notebooks/ressour...
# 3238  /content/drive/MyDrive/Colab Notebooks/ressour...
# 3239  /content/drive/MyDrive/Colab Notebooks/ressour...
# 3240  /content/drive/MyDrive/Colab Notebooks/ressour...
# 3241  /content/drive/MyDrive/Colab Notebooks/ressour...
#
#                                   hash                 label
# 0     003ff5c19b37a2b79bb169b95d2e30de               landing
# 1     0043a18428f34c7aebba1146780dc77b               article
# 2     00569945c8433ea0e859e78d3973690c               landing
# 3     0057fa9ca754fb8e46a3b74f07942bdc               landing
# 4     00837ecb034b5f4570d1e073a597f6cf   company_information
# ...                                ...                   ...
# 3237  ff85349e89a648edb9cd359c2378328c               landing
# 3238  ff8f4abb330a219836b3da6fb9f66742               landing
# 3239  ffdd799c052b7994619c51a1abe20316               article
# 3240  ffef4a742bffa072fe251922c9a46b30   company_information
# 3241  fffbf251bbb255172584ca1791d8f775                social
#
# [3242 rows x 3 columns]

# %%
dataset.columns
# Out:
# Index(['raw_filename', 'hash', 'label'], dtype='object')

# %%
dataset['label'].value_counts()
# Out:
#  company_information    1075
#  landing                1012
#  social                  630
#  article                 521
#  commercial                4
# Name: label, dtype: int64

# %% [markdown]
# Taking only the lightest pages shows that the commercial ones tend to be really heave, and the articles are twice as likely to be heavier than a company information or landing page.

# %% [markdown]
# # Focus on what we have
#
# Lets try to predict whether a page is a landing, or not.

# %%
dataset['is_landing'] = dataset.label.str.contains('landing')

# %%
dataset.is_landing.value_counts()
# Out:
# False    2230
# True     1012
# Name: is_landing, dtype: int64

# %% [markdown]
# Restore balance by dropping half of False samples:

# %%
false_dataset = dataset[dataset.is_landing == False].sample(n=1012)

# %% [markdown]
# We can see that the "not-a-landing page" values have hidden labels which are present in same repartition as the initial sample thanks to the sample function. (although, the initial sample is biased from the start, so it doesn't matter that much)

# %%
false_dataset.label.value_counts()
# Out:
#  company_information    485
#  social                 293
#  article                232
#  commercial               2
# Name: label, dtype: int64

# %%
balanced_dataset = pd.concat([false_dataset, dataset[dataset.is_landing == True]])

# %%
balanced_dataset.is_landing.value_counts()
# Out:
# False    1012
# True     1012
# Name: is_landing, dtype: int64

# %% [markdown]
# # Export for next notebook

# %%
balanced_dataset.to_csv('/content/drive/MyDrive/Colab Notebooks/ressources/keywi/landing_dataset.csv')
